# %%
import geopandas as gpd
import pandas as pd

arquivo_geojson = gpd.read_file("../Processed/Educação/NovasConstruçõesANDLocacao.geojson", driver="GeoJSON")
arquivo_csv = "../Processed/Educação/NovasConstruçõesANDLocacao.csv"
# Out:
# c:\Users\Desenvolvimento\AppData\Local\anaconda3\Lib\site-packages\pyogrio\raw.py:198: RuntimeWarning: driver GeoJSON does not support open option DRIVER
#   return ogr_read(

# %%
arquivo_geojson['PRAZO_ENTREGA'] = ""

# %%
arquivo_geojson.loc[1, 'PRAZO_ENTREGA'] = "12/07/2026"

# %%
arquivo_geojson.to_file("../Processed/Educação/NovasConstruçõesANDLocacao2.geojson", driver="GeoJSON")
